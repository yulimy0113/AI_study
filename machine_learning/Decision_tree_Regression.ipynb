# %% [markdown]
# ## Decision Tree

# %% [markdown]
# ### - Trees
# * Classification Tree : to predict fixed or categorical targets
# * Regression Tree : to predict targets' value
#
# ### - Ensemble Methods
# * Bagging : Bootstrap AGgregation, Train each trees independently
# * Random Forests : Decorrelated trees, Split only randomly selected m trees
# * Boosting : Train each trees by order (unlike Bagging)

# %% [markdown]
# ### 2. Regression Tree

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.tree import DecisionTreeRegressor
import warnings
warnings.filterwarnings(action='ignore')

# %%
# Create a random dataset.
RANDOM_SEED = 12

rand = np.random.RandomState(RANDOM_SEED)
X = np.sort(5*rand.rand(80, 1), axis=0)
y = np.sort(X).ravel()

y[::5] += 5 * (0.5 - rand.rand(16))
y
# Out:
# array([-0.67563131,  0.07287481,  0.10404899,  0.13953894,  0.15575535,
#        -1.64521867,  0.17584131,  0.24109375,  0.27509997,  0.36735022,
#        -1.78682521,  0.5680086 ,  0.58136509,  0.67605089,  0.68604661,
#         1.04267894,  0.80358377,  0.88782088,  1.04250244,  1.1042626 ,
#         0.46678691,  1.38558607,  1.41914176,  1.44793392,  1.5008503 ,
#        -0.57216558,  1.63784738,  1.67323765,  1.86861574,  2.00315814,
#         1.43608418,  2.08184829,  2.09625135,  2.12026223,  2.21935928,
#         3.14361339,  2.3072013 ,  2.31574435,  2.3275405 ,  2.35614889,
#         3.30285236,  2.42688707,  2.46368653,  2.53278038,  2.60613014,
#         3.65894693,  2.66869697,  2.76018817,  2.86202258,  2.97576228,
#         0.7296909 ,  3.02888847,  3.03041592,  3.12291056,  3.18099997,
#         3.67859874,  3.32628716,  3.35726323,  3.51311178,  3.66260349,
#         1.43285078,  3.70024848,  3.82280225,  3.83737825,  3.84067077,
#         2.23163046,  4.08084149,  4.12504627,  4.26367771,  4.44223764,
#         3.52907704,  4.50357427,  4.59373504,  4.72112568,  4.72290731,
#         7.23512778,  4.78474668,  4.81298452,  4.8902904 ,  4.9756908 ])

# %%
# Fit models.
reg = DecisionTreeRegressor()
reg.fit(X, y)

reg_1 = DecisionTreeRegressor(max_depth=5)
reg_1.fit(X, y)

reg_2 = DecisionTreeRegressor(max_depth=5, max_leaf_nodes=3)
reg_2.fit(X, y)
# Out:
# DecisionTreeRegressor(max_depth=5, max_leaf_nodes=3)

# %%
# Predict the results.
X_test = np.arange(0.0, 5.0, 0.01)[:, np.newaxis]

y_1 = reg_1.predict(X_test)
y_2 = reg_2.predict(X_test)

# Plot the results.
plt.figure()
plt.scatter(X, y, s=20,
           edgecolors="black",
           c="darkorange",
           label="Data")
plt.plot(X_test, y_1,
        color="green",
        label="regressor1",
        linewidth=2)
plt.plot(X_test, y_2,
        color="blue",
        label="regressor2",
        linewidth=2)
plt.xlabel("Data")
plt.ylabel("Target")
plt.title("Decision Tree Regressors")
plt.legend()
plt.show()
